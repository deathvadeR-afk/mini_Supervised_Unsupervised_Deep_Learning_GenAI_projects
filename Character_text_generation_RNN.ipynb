# %% [markdown]
# <a href="https://colab.research.google.com/github/deathvadeR-afk/mini_Deep_Learning_projects/blob/main/Character_text_generation_RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #This project is a character-level text generation model using a Recurrent Neural Network (RNN) built with TensorFlow.
#
# Here's a breakdown of what the code does:
#
# ##Loads and Preprocesses Data: It downloads the text of "Alice in Wonderland", creates a vocabulary of unique characters, and converts the text into numerical representations.
# ##Prepares Training Data: It creates sequences of characters and their corresponding target characters to train the model.
# ##Builds and Trains an RNN Model: It defines a Sequential model with an Embedding layer, a SimpleRNN layer, and a Dense output layer. This model is trained on the prepared text data to learn the patterns and sequences of characters.
# ##Generates Text: After training, the model can be used to generate new text character by character, starting from a given prompt string.
# In essence, the project trains a model to predict the next character in a sequence, allowing it to generate text that mimics the style and patterns of the training data.

# %%
import tensorflow as tf
import numpy as np
import os
import time

# Load "Alice in Wonderland" text dataset
path_to_file = tf.keras.utils.get_file('alice.txt', 'https://www.gutenberg.org/files/11/11-0.txt')
text = open(path_to_file, 'rb').read().decode(encoding='utf-8')

# Preprocess the text
vocab = sorted(set(text))
char2idx = {u: i for i, u in enumerate(vocab)}
idx2char = np.array(vocab)
text_as_int = np.array([char2idx[c] for c in text])

# Prepare training sequences
seq_length = 100
examples_per_epoch = len(text)//(seq_length+1)

char_dataset = tf.data.Dataset.from_tensor_slices(text_as_int)
sequences = char_dataset.batch(seq_length+1, drop_remainder=True)

def split_input_target(chunk):
    input_text = chunk[:-1]
    target_text = chunk[1:]
    return input_text, target_text

dataset = sequences.map(split_input_target)

# Create training batches
BATCH_SIZE = 64
BUFFER_SIZE = 10000
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)

# Build the RNN model
vocab_size = len(vocab)
embedding_dim = 256
rnn_units = 1024

rnn_model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim),  # Remove batch_input_shape
    tf.keras.layers.SimpleRNN(rnn_units,
                              return_sequences=True,
                              stateful=True,
                              recurrent_initializer='glorot_uniform'),
    tf.keras.layers.Dense(vocab_size)
])

# Compile the model
rnn_model.compile(optimizer='adam', loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True))

# Training the model
EPOCHS = 100

checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}.weights.h5")
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_prefix,
    save_weights_only=True
)

history = rnn_model.fit(dataset, epochs=EPOCHS, callbacks=[checkpoint_callback])
# Out:
# Epoch 1/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 4.0720
# Epoch 2/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 2.7740
# Epoch 3/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 2.4335
# Epoch 4/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 2.2491
# Epoch 5/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 2.1248
# Epoch 6/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 2.0315
# Epoch 7/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.9372
# Epoch 8/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 1.8746
# Epoch 9/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.8106
# Epoch 10/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 1.7426
# Epoch 11/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 1.6922
# Epoch 12/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 1.6378
# Epoch 13/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 1.5798
# Epoch 14/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 1.5523
# Epoch 15/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 1.5098
# Epoch 16/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 1.4612
# Epoch 17/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 1.4274
# Epoch 18/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 1.3893
# Epoch 19/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 1.3582
# Epoch 20/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 1.3137
# Epoch 21/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 1.2899
# Epoch 22/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 1.2626
# Epoch 23/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 1.2289
# Epoch 24/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 1.2059
# Epoch 25/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 1.1704
# Epoch 26/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 1.1455
# Epoch 27/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 1.1106
# Epoch 28/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.0925
# Epoch 29/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 1.0652
# Epoch 30/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 1.0298
# Epoch 31/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 1.0002
# Epoch 32/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.9765
# Epoch 33/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.9489
# Epoch 34/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.9293
# Epoch 35/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.8922
# Epoch 36/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.8660
# Epoch 37/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.8353
# Epoch 38/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.8244
# Epoch 39/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.7955
# Epoch 40/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.7630
# Epoch 41/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.7319
# Epoch 42/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.7112
# Epoch 43/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.6840
# Epoch 44/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.6573
# Epoch 45/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.6281
# Epoch 46/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.6186
# Epoch 47/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.5819
# Epoch 48/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.5716
# Epoch 49/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.5467
# Epoch 50/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.5229
# Epoch 51/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.5064
# Epoch 52/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.4894
# Epoch 53/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.4743
# Epoch 54/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.4571
# Epoch 55/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.4375
# Epoch 56/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.4227
# Epoch 57/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.4174
# Epoch 58/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.4032
# Epoch 59/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.3920
# Epoch 60/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.3822
# Epoch 61/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.3735
# Epoch 62/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 0.3675
# Epoch 63/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.3550
# Epoch 64/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.3489
# Epoch 65/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.3370
# Epoch 66/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.3345
# Epoch 67/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.3283
# Epoch 68/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.3251
# Epoch 69/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.3164
# Epoch 70/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.3079
# Epoch 71/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2999
# Epoch 72/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2946
# Epoch 73/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2906
# Epoch 74/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2920
# Epoch 75/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2922
# Epoch 76/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 0.2860
# Epoch 77/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2846
# Epoch 78/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.2747
# Epoch 79/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2713
# Epoch 80/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2707
# Epoch 81/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.2703
# Epoch 82/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2664
# Epoch 83/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.2639
# Epoch 84/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2619
# Epoch 85/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.2574
# Epoch 86/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2557
# Epoch 87/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.2545
# Epoch 88/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2503
# Epoch 89/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.2473
# Epoch 90/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2465
# Epoch 91/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2464
# Epoch 92/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.2422
# Epoch 93/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2418
# Epoch 94/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2417
# Epoch 95/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2368
# Epoch 96/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2403
# Epoch 97/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.2381
# Epoch 98/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2349
# Epoch 99/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2334
# Epoch 100/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2287

# %%
load_weights_path = './training_checkpoints/ckpt_20.weights.h5'
rnn_model.load_weights(load_weights_path)

# %%
history = rnn_model.fit(dataset, epochs=300, callbacks=[checkpoint_callback])
# Out:
# Epoch 1/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 1.2928
# Epoch 2/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.2718
# Epoch 3/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 1.2275
# Epoch 4/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.2046
# Epoch 5/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.1773
# Epoch 6/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.1454
# Epoch 7/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 1.1183
# Epoch 8/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 1.0921
# Epoch 9/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.0669
# Epoch 10/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.0326
# Epoch 11/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 1.0024
# Epoch 12/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.9743
# Epoch 13/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.9561
# Epoch 14/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.9235
# Epoch 15/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.8982
# Epoch 16/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.8630
# Epoch 17/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.8431
# Epoch 18/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.8094
# Epoch 19/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.7874
# Epoch 20/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.7667
# Epoch 21/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.7301
# Epoch 22/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.7056
# Epoch 23/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.6808
# Epoch 24/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.6523
# Epoch 25/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.6419
# Epoch 26/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.6151
# Epoch 27/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.5938
# Epoch 28/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.5658
# Epoch 29/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.5439
# Epoch 30/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.5212
# Epoch 31/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.5020
# Epoch 32/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.4916
# Epoch 33/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.4770
# Epoch 34/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.4612
# Epoch 35/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.4414
# Epoch 36/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.4306
# Epoch 37/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.4187
# Epoch 38/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.3998
# Epoch 39/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.3865
# Epoch 40/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.3784
# Epoch 41/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.3727
# Epoch 42/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 0.3646
# Epoch 43/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.3511
# Epoch 44/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.3475
# Epoch 45/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.3373
# Epoch 46/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.3306
# Epoch 47/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.3239
# Epoch 48/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.3156
# Epoch 49/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.3134
# Epoch 50/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.3121
# Epoch 51/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.3031
# Epoch 52/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2943
# Epoch 53/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2935
# Epoch 54/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2901
# Epoch 55/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2856
# Epoch 56/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2842
# Epoch 57/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.2847
# Epoch 58/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2747
# Epoch 59/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2735
# Epoch 60/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.2711
# Epoch 61/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2693
# Epoch 62/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2700
# Epoch 63/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2604
# Epoch 64/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2614
# Epoch 65/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.2557
# Epoch 66/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2528
# Epoch 67/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2538
# Epoch 68/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.2560
# Epoch 69/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2502
# Epoch 70/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 0.2457
# Epoch 71/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.2447
# Epoch 72/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2445
# Epoch 73/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2472
# Epoch 74/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2410
# Epoch 75/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2431
# Epoch 76/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.2397
# Epoch 77/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.2373
# Epoch 78/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.2366
# Epoch 79/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.2322
# Epoch 80/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.2288
# Epoch 81/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2274
# Epoch 82/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2318
# Epoch 83/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2313
# Epoch 84/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.2250
# Epoch 85/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2218
# Epoch 86/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2268
# Epoch 87/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.2303
# Epoch 88/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2256
# Epoch 89/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2217
# Epoch 90/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.2190
# Epoch 91/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2211
# Epoch 92/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2233
# Epoch 93/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2245
# Epoch 94/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2199
# Epoch 95/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.2197
# Epoch 96/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 0.2158
# Epoch 97/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.2156
# Epoch 98/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.2147
# Epoch 99/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.2169
# Epoch 100/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2163
# Epoch 101/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2182
# Epoch 102/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.2169
# Epoch 103/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2112
# Epoch 104/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2140
# Epoch 105/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2159
# Epoch 106/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.2127
# Epoch 107/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.2156
# Epoch 108/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2109
# Epoch 109/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2131
# Epoch 110/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.
300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 0.2029
# Epoch 230/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2040
# Epoch 231/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.2013
# Epoch 232/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.1983
# Epoch 233/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.1986
# Epoch 234/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.2017
# Epoch 235/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.1976
# Epoch 236/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.1946
# Epoch 237/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.1979
# Epoch 238/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.1962
# Epoch 239/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.1914
# Epoch 240/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.1947
# Epoch 241/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.1920
# Epoch 242/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.1889
# Epoch 243/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.1913
# Epoch 244/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.1924
# Epoch 245/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.1964
# Epoch 246/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.1895
# Epoch 247/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.1952
# Epoch 248/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.1884
# Epoch 249/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.1867
# Epoch 250/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.1864
# Epoch 251/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.1846
# Epoch 252/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.1872
# Epoch 253/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.1856
# Epoch 254/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.1863
# Epoch 255/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.1841
# Epoch 256/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.1853
# Epoch 257/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.1861
# Epoch 258/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.1894
# Epoch 259/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.1942
# Epoch 260/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.1934
# Epoch 261/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2012
# Epoch 262/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.2022
# Epoch 263/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2077
# Epoch 264/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.2135
# Epoch 265/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.2276
# Epoch 266/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2422
# Epoch 267/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2671
# Epoch 268/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.3065
# Epoch 269/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.3459
# Epoch 270/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.3962
# Epoch 271/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.4389
# Epoch 272/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.4837
# Epoch 273/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.5044
# Epoch 274/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.4667
# Epoch 275/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.4224
# Epoch 276/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.3779
# Epoch 277/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 0.3576
# Epoch 278/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.3311
# Epoch 279/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.3060
# Epoch 280/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2855
# Epoch 281/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2741
# Epoch 282/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.2522
# Epoch 283/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.2426
# Epoch 284/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.2306
# Epoch 285/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2198
# Epoch 286/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.2071
# Epoch 287/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2026
# Epoch 288/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.1950
# Epoch 289/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.1854
# Epoch 290/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.1833
# Epoch 291/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.1806
# Epoch 292/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.1793
# Epoch 293/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.1739
# Epoch 294/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.1684
# Epoch 295/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.1717
# Epoch 296/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.1678
# Epoch 297/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.1666
# Epoch 298/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.1667
# Epoch 299/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.1639
# Epoch 300/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.1669

# %%
# Generating text using the trained model
def generate_text(model, start_string):
    num_generate = 1000
    input_eval = [char2idx[s] for s in start_string]
    input_eval = tf.expand_dims(input_eval, 0)

    text_generated = []
    temperature = 1.0

    model.layers[1].reset_states()
    for i in range(num_generate):
        predictions = model(input_eval)
        predictions = predictions[0]
        predictions = predictions / temperature
        predicted_id = tf.random.categorical(predictions, num_samples=1)[-1,0].numpy()

        input_eval = tf.expand_dims([predicted_id], 0)
        text_generated.append(idx2char[predicted_id])

    return start_string + ''.join(text_generated)

print(generate_text(rnn_model, start_string="Alice was"))
# Out:
# Alice was
# not going
#     Hearound.
#
# “That’s very curious!” she thought. “But
# everything’s curious today. I think I may at once to herself, “in my going out altogether, like a candle, satidly into the can_was ly,
# “and hand round the refreshments!”
# But there seemed to be no chance of getting up and
# picking the daisied. “What do you know about the trumpet, and then
# unrolled the parchment scroll, and read as follows:—
#
# “The Queen of Hearts, she tried the
# little golden key, and when she
# was to go after that savage Queen: so, what am I to do
# with this creature when I get it home?” when it gavennt t_ the use of this ointment—one shilling the box—
#     Allow me to s you might like to try that it might not
# escape again, and took the thimble, looking as solemn as
# she remembered how small
# she was talking. “Huttle around, this git with its mouth open, gazing one side and u inioticed about in the conversation and she tried to crmber flamingoes, and the soldiers had to doubling into
# her eyes; and once she rema
